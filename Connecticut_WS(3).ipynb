# %%
import pandas as pd
import geopandas as gpd
import folium

# %%
df = pd.read_csv('Desktop/Artificial Intelligence/Connecticut Weather_Stations.csv')

# %%
df.head()
# Out:
#                            Station  Longitude   Latitude
# 0  Bridgeport Sikorsky Mem Airport    -73.1270    41.1640
# 1                 Bulls Bridge Dam    -73.4830    41.6500
# 2                       Burlington    -72.9700    41.7700
# 3                   Cockaponset Rs    -72.5197    41.4614
# 4                         Coventry    -72.3100    41.7700

# %%
gdf = gpd.GeoDataFrame(
    df, 
    geometry=gpd.points_from_xy(df['Longitude '], df['Latitude ']),
    crs="EPSG:4326"  # Standard WGS84 coordinate reference system
)
gdf.head()
# Out:
#                            Station  Longitude   Latitude   \
# 0  Bridgeport Sikorsky Mem Airport    -73.1270    41.1640
# 1                 Bulls Bridge Dam    -73.4830    41.6500
# 2                       Burlington    -72.9700    41.7700
# 3                   Cockaponset Rs    -72.5197    41.4614
# 4                         Coventry    -72.3100    41.7700
#
#                    geometry
# 0    POINT (-73.127 41.164)
# 1     POINT (-73.483 41.65)
# 2      POINT (-72.97 41.77)
# 3  POINT (-72.5197 41.4614)
# 4      POINT (-72.31 41.77)

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.columns
# Out:
# Index(['Station', 'Longitude ', 'Latitude ', 'geometry'], dtype='object')

# %%
# Lengths of variables a, b and c are the same
a = ['Bridgeport Sikorsky Mem Airport', 'Bulls Bridge Dam', 'Burlington', 'Cockaponset Rs', 'Coventry', 'Danbury', 'Falls Village', 'Groton',
     'Hartford Brainard Fd', 'Hartford Bradley International Airport', 'Mansfield Hollow Lake', 'Middletown 4 W', 'Mount Carmel', 'New Haven',
     'Norfolk 2 Sw', 'Norwich Pub Util Plt', 'Shepaug Dam', 'Stamford 5 N', 'Storrs', 'West Thompson Lake', 'Wigwam Reservoir']
b = gdf['Longitude ']
c = gdf['Latitude ']
                
m = folium.Map(location=[c[11], b[11]],
                 zoom_start=9)

# This 'for' loop creates an interactive map with a marker at each of the 21 weather
# stations in Connecticut
for i in range(len(a)):
     folium.Marker([c[i], b[i]],
                  popup=a[i]).add_to(m)  
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9c941d2fc06154a64d3f47b1b7a462a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9c941d2fc06154a64d3f47b1b7a462a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9c941d2fc06154a64d3f47b1b7a462a = L.map(
#                 &quot;map_a9c941d2fc06154a64d3f47b1b7a462a&quot;,
#                 {
#                     center: [41.55, -72.66],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_adc746f05c4434a25836a51fbccdfcac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_adc746f05c4434a25836a51fbccdfcac.addTo(map_a9c941d2fc06154a64d3f47b1b7a462a);
#
#
#             var marker_17bf049a416c1c23cdc4994b735ae7be = L.marker(
#                 [41.164, -73.127],
#                 {
# }
#             ).addTo(map_a9c941d2fc06154a64d3f47b1b7a462a);
#
#
#         var popup_d0c2f90d194a2efecbe5b0ea9b7dce38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e6e78f9b1258c953c64dbe9fcf239fa = $(`&lt;div id=&quot;html_4e6e78f9b1258c953c64dbe9fcf239fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bridgeport Sikorsky Mem Airport&lt;/div&gt;`)[0];
#                 popup_d0c2f90d194a2efecbe5b0ea9b7dce38.setContent(html_4e6e78f9b1258c953c64dbe9fcf239fa);
#
#
#
#         marker_17bf049a416c1c23cdc4994b735ae7be.bindPopup(popup_d0c2f90d194a2efecbe5b0ea9b7dce38)
#         ;
#
#
#
#
#             var marker_904874c28f93928415c1331b85c90ab9 = L.marker(
#                 [41.65, -73.483],
#                 {
# }
#             ).addTo(map_a9c941d2fc06154a64d3f47b1b7a462a);
#
#
#         var popup_d18d038a87f2440b5fdf7e0b597fb9fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_172d55ea8e4b6b0e070dc83e7122e5fc = $(`&lt;div id=&quot;html_172d55ea8e4b6b0e070dc83e7122e5fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bulls Bridge Dam&lt;/div&gt;`)[0];
#                 popup_d18d038a87f2440b5fdf7e0b597fb9fa.setContent(html_172d55ea8e4b6b0e070dc83e7122e5fc);
#
#
#
#         marker_904874c28f93928415c1331b85c90ab9.bindPopup(popup_d18d038a87f2440b5fdf7e0b597fb9fa)
#         ;
#
#
#
#
#             var marker_7302127902530ea8cf9a736697978241 = L.marker(
#                 [41.77, -72.97],
#                 {
# }
#             ).addTo(map_a9c941d2fc06154a64d3f47b1b7a462a);
#
#
#         var popup_b4caebebcb1badb7501d3b5df51b86a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92afe8eab8f7c3d59fa3ea564de9cb4f = $(`&lt;div id=&quot;html_92afe8eab8f7c3d59fa3ea564de9cb4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Burlington&lt;/div&gt;`)[0];
#                 popup_b4caebebcb1badb7501d3b5df51b86a8.setContent(html_92afe8eab8f7c3d59fa3ea564de9cb4f);
#
#
#
#         marker_7302127902530ea8cf9a736697978241.bindPopup(popup_b4caebebcb1badb7501d3b5df51b86a8)
#         ;
#
#
#
#
#             var marker_32cab9ae8a0edcac47704490086d50fd = L.marker(
#                 [41.4614, -72.5197],
#                 {
# }
#             ).addTo(map_a9c941d2fc06154a64d3f47b1b7a462a);
#
#
#         var popup_a2a897e8ce0f25d98f8ca6b23d7d8def = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c050c728408ec717bfc955e40f07cfc = $(`&lt;div id=&quot;html_8c050c728408ec717bfc955e40f07cfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cockaponset Rs&lt;/div&gt;`)[0];
#                 popup_a2a897e8ce0f25d98f8ca6b23d7d8def.setContent(html_8c050c728408ec717bfc955e40f07cfc);
#
#
#
#         marker_32cab9ae8a0edcac47704490086d50fd.bindPopup(popup_a2a897e8ce0f25d98f8ca6b23d7d8def)
#         ;
#
#
#
#
#             var marker_34ac572021173fac85643691e3b6bf61 = L.marker(
#                 [41.77, -72.31],
#                 {
# }
#             ).addTo(map_a9c941d2fc06154a64d3f47b1b7a462a);
#
#
#         var popup_adeb011df78351cd64554b9dcab20e6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef5971730eeb2eab5d20fc41ddc7aad5 = $(`&lt;div id=&quot;html_ef5971730eeb2eab5d20fc41ddc7aad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coventry&lt;/div&gt;`)[0];
#                 popup_adeb011df78351cd64554b9dcab20e6c.setContent(html_ef5971730eeb2eab5d20fc41ddc7aad5);
#
#
#
#         marker_34ac572021173fac8564369
